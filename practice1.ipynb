# %% [markdown]
# # Comments

# %%
a = int(input())
b = int(input())
c = int(input())

# Prints a
print(a)

# Prints b
#print(b) Here commenting the print st

# Prints c
print(c)

# %% [markdown]
# # Print

# %%
""" You'll be given two strings a and b, a separator symbol, and you need to print
a and b such that a and b are separated by the separator symbol followed by a new line."""
# Input: a = "Hello", b = "World", separator = "@"
# Output: Hello@World
# Explanation: a and b are printed with the separator symbol in between.

a = input()
b = input()
separator = input()
print(a+separator+b)

# %% [markdown]
# # MUlti Printing

# %%
a = input()
n = int(input())
#code here

for i in range(n):
    print(a,end="")

# %% [markdown]
# # Conversion

# %%
a = input()
b = input()
c = input()
# Write your code below that prints a a times and b b times, seperated by c

print(int(a)*a +c+  b * int(b))

# %%
echo "# Python-Practice" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/gopikrishna7-hash/Python-Practice.git
git push -u origin main
# Out:
#   Cell In[5], line 1
#     echo "# Python-Practice" >> README.md
#          ^
# SyntaxError: invalid syntax
