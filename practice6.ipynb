# %%
# Given two strings a and b of different lengths. 
# Construct a new string by placing the shorter string at both the beginning and the end, and the longer string in the middle. 
# Return the newly formed string.

def combineStrings( a: str, b: str) :
    # code here
    res=''
    len_a=len(a)
    len_b=len(b)
    if len_a >len_b:
        res=b+a+b
    else:
        res=a+b+a
    return res
combineStrings("Hell","Outoff")
# Out:
# 'HellOutoffHell'

# %%
# Python has a lot of string methods that can be used to manipulate the strings like converting to lowercase, capitalizing, trimming the spaces and so on.
# In this question, we'll take a look at inbuilt string methods like title(), swapcase(), find(), strip().
# You'll be given a string str and x, you'll perform various operations on them.
def trim(str):
    return str.strip()

def exists(str, x):
    return str.find(x)

def titleIt(str):
    return str.title()

def casesSwap(str):
    return str.swapcase()

# %%
# Given a string s. The task is to convert string characters to lowercase.

def toLower ( s) :
        # code here 
    return s.lower()
toower("HI everyONE")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2
#       3 def toLower ( s) :
#       4         # code here
#       5     return s.lower()
# ----> 6 tolower("HI everyONE")
#
# NameError: name 'tolower' is not defined

# %%
# You are given a string s, and your task is to reverse the string.

def reverseString( s) :
    # code here
    rev_str=""
    for l in s:
        rev_str=l + rev_str
        
    return rev_str
reverseString("IEveryone..!")
# Out:
# '!..enoyrevEI'

# %%
# Given a string s, you need to check if it is palindrome or not. 
# A palidrome is a string that reads the same from front and back.
# Note: Ignore the case in this question.
def isPalindrome(s):
    #code here
    s=s.lower()
    len_a=len(s)
    
    i=0
    j=len_a-1
    while i <j:
        if s[i] != s[j]:
            return False
        i+=1
        j-=1
    return True
isPalindrome("EVERYYREVE")
# Out:
# True
