# %%
# Given three numbers a, b and c. Find the greatest number among them.
a = int(input())
b = int(input())
c = int(input())

# code here
if a > b and a>c:
    print(a)
elif b>a and b>c:
    print(b)
else:
    print(c)
# Out:
#  134
#  23
#  234
# 234
